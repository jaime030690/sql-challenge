# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import psycopg2
from config import postgresql_pass

# %%
# Connect to SQL database
url = f'postgresql+psycopg2://postgres:{postgresql_pass}@localhost:5432/sql-challenge'
engine = create_engine(url)
connection = engine.connect()

# %%
# Create dataframe to hold salary information
salaries = pd.read_sql_table('salaries', connection)
salaries.dropna(inplace = True)
salaries.head()
# Out:
#    emp_no  salary  from_date    to_date
# 0   10001   60117 1986-06-26 1987-06-26
# 1   10002   65828 1996-08-03 1997-08-03
# 2   10003   40006 1995-12-03 1996-12-02
# 3   10004   40054 1986-12-01 1987-12-01
# 4   10005   78228 1989-09-12 1990-09-12

# %%
# Create a histogram to visualize the most common salary ranges for employees.
plt.hist(salaries['salary'])
plt.title('Salary Ranges for Employees')
plt.xlabel('Salary')
plt.ylabel('Employees')
plt.show()

# %%
# Create dataframe to hold for average salaries by title
title = pd.read_sql_query('SELECT title, AVG(sal.salary) as "average" FROM titles JOIN employees AS emp ON titles.emp_no = emp.emp_no JOIN salaries AS sal ON emp.emp_no = sal.emp_no GROUP BY title;', connection)
title.dropna(inplace = True)
title
# Out:
#                 title       average
# 0  Assistant Engineer  48493.204786
# 1            Engineer  48539.781423
# 2             Manager  51531.041667
# 3     Senior Engineer  48506.751806
# 4        Senior Staff  58503.286614
# 5               Staff  58465.271904
# 6    Technique Leader  48580.505772

# %%
# Create a bar chart of average salary by title
plt.bar(title['title'], title['average'])
plt.xticks(rotation = 45)
plt.title('Average Salary by Title')
plt.xlabel('Title')
plt.ylabel('Average Salary')
plt.show()
